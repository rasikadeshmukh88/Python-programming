# %%
#Task:withdraw the amount from bank if available
balance=15000
amount=int(input("Enter the amount for withdraw :"))
if amount>0:
    if amount>0 and amount<=balance:
        print("amount withdraw successfully...")
        print("Available balance is:",balance-amount)
    elif amount>balance:
        print("Insufficient balance")
else:
    print("Enter valid amount")
# Out:
# Enter the amount for withdraw : 5000
# amount withdraw successfully...
# Available balance is: 10000
